# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("A.csv")

# %%
df2=pd.read_csv("B.csv")

# %%
df3=pd.read_csv("C.csv")

# %%
df4=pd.read_csv("D.csv")

# %%
df5=pd.read_csv("E.csv")

# %%
df6=pd.read_csv("F.csv")

# %%
df7=pd.read_csv("G.csv")

# %%
df8=pd.read_csv("H.csv")

# %%
df9=pd.read_csv("I.csv")

# %%
df10=pd.read_csv("J.csv")

# %%
df11=pd.read_csv("K.csv")

# %%
df12=pd.read_csv("L.csv")

# %%
df13=pd.read_csv("U.csv")

# %%
df14=pd.read_csv("V.csv")

# %%
df15=pd.read_csv("W.csv")

# %%
df16=pd.read_csv("Y.csv")

# %%
df17=pd.read_csv("no1.csv")

# %%
df15
# Out:
#      Unnamed: 0   0x   0y   1x   1y   2x   2y   3x   3y   4x  ...  16x  16y  \
# 0             0  180  385  214  364  229  333  207  309  176  ...  132  165
# 1             1  180  385  210  367  228  331  202  311  166  ...  120  166
# 2             2  180  379  211  361  228  330  203  309  171  ...  125  161
# 3             3  174  376  203  356  219  322  190  302  155  ...  116  157
# 4             4  164  371  195  351  211  319  186  297  154  ...  102  153
# ..          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 205         205  146  384  170  367  182  337  155  323  122  ...   59  189
# 206         206  147  384  172  367  183  338  160  325  130  ...   66  191
# 207         207  157  386  181  368  193  337  170  323  137  ...   75  188
# 208         208  157  390  184  372  197  339  169  325  134  ...   79  189
# 209         209  159  392  185  375  199  343  172  328  137  ...   82  190
#
#      17x  17y  18x  18y  19x  19y  20x  20y
# ...

# %%
df1['target']=['A']*len(df1)

# %%
df2['target']=['B']*len(df2)

# %%
df3['target']=['C']*len(df3)

# %%
df4['target']=['D']*len(df4)

# %%
df5['target']=['E']*len(df5)

# %%
df6['target']=['F']*len(df6)

# %%
df7['target']=['G']*len(df7)

# %%
df8['target']=['H']*len(df8)

# %%
df9['target']=['I']*len(df9)

# %%
df10['target']=['J']*len(df10)

# %%
df11['target']=['K']*len(df11)

# %%
df12['target']=['L']*len(df12)

# %%
df13['target']=['U']*len(df13)

# %%
df14['target']=['V']*len(df14)

# %%
df15['target']=['W']*len(df15)

# %%
df16['target']=['Y']*len(df16)

# %%
df17['target']=['one']*len(df17)

# %%
df4[df4['target']==np.nan]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 0x, 0y, 1x, 1y, 2x, 2y, 3x, 3y, 4x, 4y, 5x, 5y, 6x, 6y, 7x, 7y, 8x, 8y, 9x, 9y, 10x, 10y, 11x, 11y, 12x, 12y, 13x, 13y, 14x, 14y, 15x, 15y, 16x, 16y, 17x, 17y, 18x, 18y, 19x, 19y, 20x, 20y, target]
# Index: []
#
# [0 rows x 44 columns]

# %% [markdown]
# ####

# %%
df16
# Out:
#      Unnamed: 0   0x   0y   1x   1y   2x   2y   3x   3y   4x  ...  16y  17x  \
# 0             0  178  226  201  228  211  232  210  236  203  ...  271  117
# 1             1  170  311  200  285  221  243  232  209  246  ...  266  105
# 2             2  182  307  215  283  239  243  250  208  263  ...  262  124
# 3             3  188  306  220  282  243  242  254  207  266  ...  261  129
# 4             4  195  263  192  260  183  248  184  241  185  ...  257  191
# ..          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 275         275  175  341  217  326  255  290  276  252  301  ...  300  136
# 276         276  184  339  227  324  264  285  285  248  303  ...  303  141
# 277         277  185  338  226  323  263  284  285  247  304  ...  303  142
# 278         278  194  322  232  320  271  283  292  245  308  ...  303  161
# 279         279  189  338  230  323  267  285  290  248  310  ...  301  150
#
#      17y  18x  18y  19x  19y  20x  20y  target
# ...

# %%
# df3[df3.isnull()==True]

# %%
# df4[df4.isnull()==True]

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17],ignore_index=True)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df = df.sample(frac=1,random_state=101).reset_index(drop=True)

# %%
df
# Out:
#        0x   0y   1x   1y   2x   2y   3x   3y   4x   4y  ...  16y  17x  17y  \
# 0     156  381  180  363  192  332  168  318  134  310  ...  182  115  299
# 1     176  312  210  290  238  248  251  211  264  185  ...  265  118  229
# 2     219  362  251  343  272  305  250  279  219  267  ...  308  178  269
# 3     188  362  217  339  230  303  204  280  176  264  ...  307  139  277
# 4      68  275   95  234  142  217  180  224  204  241  ...  274  156  296
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 3390  156  336  190  317  218  288  236  266  246  246  ...  237  138  252
# 3391  181  352  224  340  268  300  273  255  245  229  ...  294  165  232
# 3392   71  280   91  233  131  215  169  228  195  242  ...  260  146  286
# 3393  117  371  161  355  199  317  197  272  168  248  ...  307   98  252
# 3394  151  365  186  344  212  314  217  284  203  262  ...  141  134  251
#
#       18x  18y  19x  19y  20x  20y  target
# ...

# %%
# df[df['target']==np.nan]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
from sklearn.model_selection import train_test_split
X=df.drop('target',axis=1)
y=df['target']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.10,random_state=101)

# %%
X_train=scale.fit_transform(X_train)
X_test=scale.transform(X_test)

# %%
from sklearn.svm import SVC

base_mod=SVC(random_state=101)

base_mod.fit(X_train,y_train)

pred=base_mod.predict(X_test)
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

accuracy_score(y_test,pred)
# Out:
# 0.9911764705882353

# %%
import pickle
filename = 'A-B-C-D-E-F-G-H-I-J-K-L-U-V-W-Y-1'
pickle.dump(base_mod, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9911764705882353

# %%
pred
# Out:
# array(['W', 'G', 'I', 'W', 'W', 'W', 'H', 'H', 'I', 'Y', 'L', 'V', 'Y',
#        'K', 'one', 'W', 'J', 'H', 'K', 'A', 'E', 'H', 'V', 'D', 'J', 'B',
#        'K', 'H', 'D', 'K', 'J', 'A', 'H', 'B', 'Y', 'K', 'D', 'L', 'Y',
#        'D', 'W', 'A', 'J', 'C', 'H', 'Y', 'D', 'J', 'B', 'Y', 'U', 'A',
#        'J', 'L', 'L', 'W', 'Y', 'I', 'B', 'H', 'V', 'Y', 'H', 'U', 'one',
#        'B', 'L', 'K', 'D', 'H', 'G', 'B', 'W', 'L', 'F', 'V', 'U', 'B',
#        'L', 'B', 'D', 'B', 'W', 'E', 'L', 'E', 'L', 'D', 'K', 'A', 'D',
#        'A', 'A', 'K', 'J', 'A', 'V', 'L', 'W', 'W', 'F', 'C', 'L', 'F',
#        'D', 'A', 'one', 'G', 'W', 'V', 'B', 'K', 'B', 'J', 'one', 'one',
#        'Y', 'A', 'Y', 'D', 'H', 'L', 'I', 'one', 'C', 'H', 'B', 'B', 'W',
#        'Y', 'J', 'W', 'I', 'B', 'one', 'E', 'Y', 'B', 'C', 'V', 'F', 'U',
#        'H', 'A', 'D', 'W', 'H', 'Y', 'G', 'Y', 'I', 'G', 'L', 'D', 'A',
#        'K', 'Y', 'I', 'D', 'K', 'L', 'B', 'L', 'one', 'I', 'W', 'L', 'D',
# ...

# %%
from sklearn.externals import joblib
scaler_filename = "scaler.save"
joblib.dump(scale, scaler_filename)
# Out:
# c:\users\asus\anaconda3\envs\deep_lenv\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['scaler.save']

# %%
scaler = joblib.load(scaler_filename)

# %%
X_test.shape
# Out:
# (340, 42)

# %%
X_train.shape
# Out:
# (3055, 42)
